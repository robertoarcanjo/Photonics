# %% [markdown]
# # JSON and HDF5

# %%
# %pip install h5py
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install tables
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/6.4 MB ? eta -:--:--
#    ---------------------------------------- 6.4/6.4 MB 61.5 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 54.0 MB/s  0:00:00
# ...
#
#    --- ------------------------------------  1/12 [urllib3]
#    --- ------------------------------------  1/12 [urllib3]
#    ------------- --------------------------  4/12 [ndindex]
#    ------------- --------------------------  4/12 [ndindex]
#    -------------------- -------------------  6/12 [idna]
#    ----------------------- ----------------  7/12 [charset_normalizer]
#    ------------------------------ ---------  9/12 [requests]
#    --------------------------------- ------ 10/12 [blosc2]
#    ------------------------------------ --- 11/12 [tables]
# ...

# %%
# JSON
import json

# H5
import h5py
import tables

# %%
file = h5py.File('data.h5', mode='w')

# %%
file.mode # read and write = r+
# Out:
# 'r+'

# %%
file.flush()

# %%
file.close()

# %% [markdown]
# ### Groups

# %%
file = h5py.File("data.h5", "w")

# %%
file.name
# Out:
# '/'

# %%
group1 = file.create_group("group1")

# %%
group1.name
# Out:
# '/group1'

# %%
group2_sim_res = file.create_group("group2/simulation_results")

# %%
group2_sim_res.name
# Out:
# '/group2/simulation_results'

# %%
group2_analysis = file.create_group("group2/analysis")

# %%
file['/group2']
# Out:
# <HDF5 group "/group2" (2 members)>

# %%
list(file.keys())
# Out:
# ['group1', 'group2']

# %%
list(file.items())
# Out:
# [('group1', <HDF5 group "/group1" (0 members)>),
#  ('group2', <HDF5 group "/group2" (2 members)>)]

# %%
file.visititems(lambda name, item: print(name, item))
# Out:
# group1 <HDF5 group "/group1" (0 members)>
# group2 <HDF5 group "/group2" (2 members)>
# group2/analysis <HDF5 group "/group2/analysis" (0 members)>
# group2/simulation_results <HDF5 group "/group2/simulation_results" (0 members)>

# %%
"group1" in file
# Out:
# True

# %%
"geoup3" in file
# Out:
# False

# %%
file.flush()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 file.flush()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\h5py\_hl\files.py:641, in File.flush(self)
#     638 """ Tell the HDF5 library to flush its buffers.
#     639 """
#     640 with phil:
# --> 641     h5f.flush(self.id)
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5f.pyx:161, in h5py.h5f.flush()
#
# RuntimeError: Unable to synchronously flush file (not a file or file object)

# %%
file.close()

# %%
file
# Out:
# <Closed HDF5 file>
